# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("aaaaaaaaaaaaaaaaaaa.csv",encoding= 'unicode_escape')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   order cancled    Month  Year        Date Invoice_Time Day/Night  UnitPrice  \
# 0            no  January  2010  12-01-2010        08:26       day       2.55
# 1            no  January  2010  12-01-2010        08:26       day       3.39
# 2            no  January  2010  12-01-2010        08:26       day       2.75
# 3            no  January  2010  12-01-2010        08:26       day       3.39
# 4            no  January  2010  12-01-2010        08:26       day       3.39
#
#     sale  CustomerID         Country
# 0  15.30     17850.0  United Kingdom
# 1  20.34     17850.0  United Kingdom
# 2  22.00     17850.0  United Kingdom
# 3  20.34     17850.0  United Kingdom
# 4  20.34     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541901    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541902    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541903    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541904    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541905    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#        order cancled    Month  Year        Date Invoice_Time Day/Night  \
# 541901            no  January  2011  10-01-2011        12:50       day
# 541902            no  January  2011  10-01-2011        12:50       day
# 541903            no  January  2011  10-01-2011        12:50       day
# 541904            no  January  2011  10-01-2011        12:50       day
# 541905            no  January  2011  10-01-2011        12:50       day
#
#         UnitPrice   sale  CustomerID Country
# 541901       0.85  10.20     12680.0  France
# 541902       2.10  12.60     12680.0  France
# 541903       4.15  16.60     12680.0  France
# 541904       4.15  16.60     12680.0  France
# 541905       4.95  14.85     12680.0  France

# %%
df.isnull().sum()
# Out:
# InvoiceNo             0
# StockCode             0
# Description        1454
# Quantity              0
# order cancled         0
# Month                 0
# Year                  0
#  Date                 0
# Invoice_Time          0
# Day/Night             0
# UnitPrice             0
# sale                  0
# CustomerID       135078
# Country               0
# dtype: int64

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541901    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541902    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541903    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541904    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541905    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        order cancled    Month  Year        Date Invoice_Time Day/Night  \
# 0                 no  January  2010  12-01-2010        08:26       day
# 1                 no  January  2010  12-01-2010        08:26       day
# 2                 no  January  2010  12-01-2010        08:26       day
# 3                 no  January  2010  12-01-2010        08:26       day
# 4                 no  January  2010  12-01-2010        08:26       day
# ...              ...      ...   ...         ...          ...       ...
# 541901            no  January  2011  10-01-2011        12:50       day
# 541902            no  January  2011  10-01-2011        12:50       day
# 541903            no  January  2011  10-01-2011        12:50       day
# 541904            no  January  2011  10-01-2011        12:50       day
# 541905            no  January  2011  10-01-2011        12:50       day
#
#         UnitPrice   sale  CustomerID         Country
# 0            2.55  15.30     17850.0  United Kingdom
# 1            3.39  20.34     17850.0  United Kingdom
# 2            2.75  22.00     17850.0  United Kingdom
# 3            3.39  20.34     17850.0  United Kingdom
# 4            3.39  20.34     17850.0  United Kingdom
# ...           ...    ...         ...             ...
# 541901       0.85  10.20     12680.0          France
# 541902       2.10  12.60     12680.0          France
# 541903       4.15  16.60     12680.0          France
# 541904       4.15  16.60     12680.0          France
# 541905       4.95  14.85     12680.0          France
#
# [541906 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# InvoiceNo             0
# StockCode             0
# Description        1454
# Quantity              0
# order cancled         0
# Month                 0
# Year                  0
#  Date                 0
# Invoice_Time          0
# Day/Night             0
# UnitPrice             0
# sale                  0
# CustomerID       135078
# Country               0
# dtype: int64

# %%
df1=df

# %%
df1.dropna(inplace=True)

# %%
df1.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541901    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541902    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541903    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541904    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541905    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#        order cancled    Month  Year        Date Invoice_Time Day/Night  \
# 541901            no  January  2011  10-01-2011        12:50       day
# 541902            no  January  2011  10-01-2011        12:50       day
# 541903            no  January  2011  10-01-2011        12:50       day
# 541904            no  January  2011  10-01-2011        12:50       day
# 541905            no  January  2011  10-01-2011        12:50       day
#
#         UnitPrice   sale  CustomerID Country
# 541901       0.85  10.20     12680.0  France
# 541902       2.10  12.60     12680.0  France
# 541903       4.15  16.60     12680.0  France
# 541904       4.15  16.60     12680.0  France
# 541905       4.95  14.85     12680.0  France

# %%
df1.isnull().sum()
# Out:
# InvoiceNo        0
# StockCode        0
# Description      0
# Quantity         0
# order cancled    0
# Month            0
# Year             0
#  Date            0
# Invoice_Time     0
# Day/Night        0
# UnitPrice        0
# sale             0
# CustomerID       0
# Country          0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406828 entries, 0 to 541905
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      406828 non-null  object
#  1   StockCode      406828 non-null  object
#  2   Description    406828 non-null  object
#  3   Quantity       406828 non-null  int64
#  4   order cancled  406828 non-null  object
#  5   Month          406828 non-null  object
#  6   Year           406828 non-null  int64
#  7    Date          406828 non-null  object
#  8   Invoice_Time   406828 non-null  object
#  9   Day/Night      406828 non-null  object
#  10  UnitPrice      406828 non-null  float64
#  11  sale           406828 non-null  float64
#  12  CustomerID     406828 non-null  float64
#  13  Country        406828 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 46.6+ MB

# %%
df1.describe()
# Out:
#             Quantity           Year     UnitPrice           sale  \
# count  406828.000000  406828.000000  406828.00000  406828.000000
# mean       12.061336    2010.956493       3.36469      20.497694
# std       248.693675       0.203996      32.74625     423.200032
# min    -80995.000000    2010.000000       0.00000 -168469.600000
# 25%         2.000000    2011.000000       1.25000       4.200000
# 50%         5.000000    2011.000000       1.95000      11.100000
# 75%        12.000000    2011.000000       3.75000      19.500000
# max     80995.000000    2011.000000    8142.75000  168469.600000
#
#           CustomerID
# count  406828.000000
# mean    15287.691037
# std      1713.602384
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000

# %%
df1.InvoiceNo.unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %%
df1.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#        'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %%
df1["Day/Night"].unique()
# Out:
# array(['day', 'night'], dtype=object)

# %%
df1.Year.unique()
# Out:
# array([2010, 2011], dtype=int64)

# %%
df1.Month.unique()
# Out:
# array(['January', 'February', 'March', 'May', 'June', 'July', 'August',
#        'September', 'October', 'December', 'April', 'November'],
#       dtype=object)

# %%
df1["order cancled"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df1.Quantity.unique()
# Out:
# array([     6,      8,      2,     32,      3,      4,     24,     12,
#            48,     18,     20,     36,     80,     64,     10,    120,
#            96,     23,      5,      1,     -1,     50,     40,    100,
#           192,    432,    144,    288,    -12,    -24,     16,      9,
#           128,     25,     30,     28,      7,     72,    200,    600,
#           480,     -6,     14,     -2,     -4,     -5,     -7,     -3,
#            11,     70,    252,     60,    216,    384,     27,    108,
#            52,  -9360,     75,    270,     42,    240,     90,    320,
#            17,   1824,    204,     69,    -36,   -192,   -144,    160,
#          2880,   1400,     19,     39,    -48,    -50,     56,     13,
#          1440,     -8,     15,    720,    -20,    156,    324,     41,
#           -10,    -72,    -11,    402,    378,    150,    300,     22,
#            34,    408,    972,    208,   1008,     26,   1000,    -25,
#          1488,    250,   1394,    400,    110,    -14,     37,    -33,
#            78,     -9,     21,    272,     84,    -47,    -18,    -96,
#            47,    -15,    -30,   1728,     38,    -60,    -16,     53,
#          -240,     76,    576,    -32,     29,   2400,    500,    -80,
#           180,   -300,   -500,    -23,    -13,    960,    -21,   1296,
#          -150,    -17,    147,    168,    256,    -40,   -100,     54,
#            31,    860,   1010,   1356,   1284,    186,    114,    360,
#          1930,   2000,   3114,   1300,    670,    176,    648,     62,
#         74215, -74215,     89,     33,     46,   -120,    112,    456,
#           900,   -600,    -42,    -94,     45,    130,   2592,    420,
#           800,     35,   1200,    864,    504,    -76,   -200,   1056,
#          1500,    280,    407,    141,   3906,   1152,    198,    117,
#          -720,    125,    -86,     81,    -35,    768,     88,     43,
#           700,   -102,   2160,     55,    -49,    342,    304,    640,
#           220,    350,    -46,    -64,    312,    392,   -624,    -27,
#           330,    151,   -432,    -58,     44,   -670,  -1300,  -1930,
#         -2000,  -3114,    462,     66,    492,    273,     65,     85,
#           -51,   -960,   1350,    428,  -1350,    336,    101,    132,
#           227,   2700,    222,    228,    246,    906,    756,    888,
#           552,    224,    738,    608,   4300,    276,    -52,     58,
#            98,     51,     74,   1600,    323,    -22,   1515,  -1515,
#           660,    104,   -420,    264,    188,    588,    612,    152,
#           -19,   -480,     49,   -164,   -160,    430,    701,    828,
#           540,    696,    560,   -576,   -108,   -250,   -408,    121,
#           512,    -37,    291,   3186,     83,     87,     79,   -360,
#           -28,    -75,    109,   -121,    129,    261,    352,    102,
#          -288,    348,   1900,    157,    -39,    116,    968,    684,
#           824,   -828,   -701,    196,    124,    248,    410,    236,
#           230,    210,    448,   -140,   -400,   -252,   -110,   -334,
#          -318,   -126,   -113,   -180,    140,     86,    840,    -38,
#           450,     93,    494,     92,   1788,    624,    744,    416,
#           496,    396,    306,   1878,   1944,    666,    708,   1428,
#           852,   1412,    528,   -756,   -152,    -85,    -34,   -312,
#           -79,    -43,    -31,    183,   -186,    -53,    -82,    -70,
#           -68,   1540,  -1200,   -130,   -220,    672,    -26,    -29,
#            67,   -840,  -1296,     63,     94,    255,     57,    126,
#           468,   -468,   -324,   -168,   4800,    -66,   -112,    912,
#          1992,    136,   3000,    -45,    232,    832,    992,    630,
#          1020,   2100,    162,   -162,    -67,   -276,   -184,    234,
#           244,   -244,   -234,   -132,  12540,     95,    760,    139,
#           115,    774,   2040,   1120,     59,    490,    388,    620,
#          1404,    698,  80995, -80995], dtype=int64)

# %%
df1.sale.unique()
# Out:
# array([ 15.3 ,  20.34,  22.  , ...,  25.08, 469.44,  66.36])

# %%
df1.corr()
# Out:
#             Quantity      Year  UnitPrice      sale  CustomerID
# Quantity    1.000000  0.001990  -0.002466  0.925592   -0.003600
# Year        0.001990  1.000000   0.001505  0.000255   -0.038874
# UnitPrice  -0.002466  0.001505   1.000000 -0.007043   -0.009328
# sale        0.925592  0.000255  -0.007043  1.000000   -0.002323
# CustomerID -0.003600 -0.038874  -0.009328 -0.002323    1.000000

# %%
f = plt.figure(figsize=(19, 8))
plt.matshow(df1.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
